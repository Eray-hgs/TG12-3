# %% [markdown]
# # Datenbanksysteme
#
# ## Mehrere Tabellen
#
# ### Datenbank Projektarbeiten
# An der Turing-Gewerbeschule werden in der Jahrgangsstufe 1 Projekte angeboten. Dazu wurde die folgende Datenbank erstellt und mit den ersten Daten gefüllt:

# %%
CREATE TABLE projekt (
    projekt_id INTEGER PRIMARY KEY,
    titel VARCHAR(100),
    fachbereich VARCHAR(50)
);

CREATE TABLE schueler (
    schueler_id INTEGER PRIMARY KEY,
    vorname VARCHAR(50),
    nachname VARCHAR(50),
    klasse VARCHAR(10),
    projekt_id INTEGER
);

INSERT INTO projekt VALUES
(10, 'Smart Home Steuerung', 'IoT'),
(11, 'Bibliotheksdatenbank', 'Datenbanken'),
(12, 'Robotik-Parcours', 'Robotik'),
(13, 'Wetterstation', 'Sensorik');

INSERT INTO schueler VALUES
(1, 'Mia', 'Keller', 'J1TG', 10),
(2, 'Jonas', 'Weber', 'J1TG', 10),
(3, 'Lina', 'Schmidt', 'J1TG', 11),
(4, 'Emir', 'Yilmaz', 'J1TG', 12),
(5, 'Noah', 'Fischer', 'J1TG', NULL);
# Out:
#   Cell In[1], line 1
#     CREATE TABLE projekt (
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Forschungsauftrag
#
# Nutze die Webseite [DB Fiddle](https://dbfiddle.uk) und wähle als *engine* **postgres** aus, um die Datenbank zu untersuchen. Kopiere dazu in das linke Eingabefeld die komplette Definition und Klicke auf `run`. Im rechten Ausgabefeld werden Meldungen vom Serverangezeigt.
#
# Führe die folgenden `SELECT`-Anweisungen aus. Vergleiche die Ergebnisse.
#
# Notiere zu jeder Abfrage:
#
# 1. Welche Schülerinnen und Schüler erscheinen?
# 2. Welche Projekte erscheinen?
# 3. Welche Zeilen fehlen?
# 4. Wo entstehen `NULL`-Werte?
# 5. Welche Regel vermutest du hinter der Verbindungsart?

# %% [markdown]
# #### Aufgabe 1: INNER JOIN

# %%
SELECT
    schueler.vorname,
    schueler.nachname,
    projekt.titel,
    projekt.fachbereich
FROM schueler
INNER JOIN projekt
ON schueler.projekt_id = projekt.projekt_id;

# %% [markdown]
# #### Beobachtung
# Noah fehlt, weil seine projekt_id den Wert NULL hat. Die Wetterstation fehlt, weil kein Schüler diesem Projekt zugeordnet ist.
#
# | Verbindungsart | Zweck |
# | --- | --- |
# | INNER JOIN | Zeigt nur Zeilen, bei denen der Wert aus schueler.projekt_id zu einem Wert aus projekt.projekt_id passt. |

# %% [markdown]
# #### Aufgabe 2: LEFT JOIN

# %%
SELECT
    schueler.vorname,
    schueler.nachname,
    projekt.titel,
    projekt.fachbereich
FROM schueler
LEFT JOIN projekt
ON schueler.projekt_id = projekt.projekt_id;

# %% [markdown]
# #### Beobachtung
#
# Noah ist da, obwohl seine projekt_id den Wert NULL hat. Die Wetterstation fehlt da kein Schüler diesem Projekt zugeordnet ist.
# Also alle Schüler werden gezeigt mit Ihrer projekt_id.
#
# | Verbindungsart | Zweck |
# | --- | --- |
# |LEFT JOIN|| Zeigt alle Zeilen der linken Tabelle an. Bei unpassenden Daten von linker und rechter Tabelle wird in der rechten Tablle NULL anngeziegt |

# %% [markdown]
# #### Aufgabe 3: RIGHT JOIN

# %%
SELECT
    schueler.vorname,
    schueler.nachname,
    projekt.titel,
    projekt.fachbereich
FROM schueler
RIGHT JOIN projekt
ON schueler.projekt_id = projekt.projekt_id;

# %% [markdown]
# #### Beobachtung
# Noah fehlt da seine projekt_id NULL ist. Die Wetterstaion wird angezeigt und dass kein Schüler diesem Projekt zugewiesen ist.
#
# | Verbindungsart | Zweck |
# |---|---|
# | RIGHT JOIN |  Zeigt alle Zeilen der rechten Tabelle an. Bei unpassenden Daten von linker und rechter Tabelle wird in der linken Tablle NULL anngeziegt  |

# %% [markdown]
# #### Aufgabe 4: FULL OUTER JOIN

# %%
SELECT
    schueler.vorname,
    schueler.nachname,
    projekt.titel,
    projekt.fachbereich
FROM schueler
FULL OUTER JOIN projekt
ON schueler.projekt_id = projekt.projekt_id;

# %% [markdown]
# #### Beobachtung
# Mischung aus LEFT JOIN und RIGHT JOIN
#
# | Verbindungsart | Zweck |
# | --- | --- |
# | FULL OUTER JOIN| Zeigt alle Zeilen beider Tabellen und bei unpassenden Daten wird NULL angezeigt. |

# %% [markdown]
# #### Aufgabe 5: Verbindung mit WHERE ohne JOIN

# %%
SELECT
    schueler.vorname,
    schueler.nachname,
    projekt.titel,
    projekt.fachbereich
FROM schueler, projekt
WHERE schueler.projekt_id = projekt.projekt_id;

# %% [markdown]
# #### Beobachtung
# Noah fehlt, weil seine projekt_id den Wert NULL hat. Die Wetterstation fehlt, weil kein Schüler diesem Projekt zugeordnet ist.
#
# | Verbindungsart | Zweck |
# | --- | --- |
# | WHERE ohne JOIN | Zeigt nur Zeilen, bei denen der Wert aus schueler.projekt_id zu einem Wert aus projekt.projekt_id passt. |

# %% [markdown]
# ### Ergebnissicherung
# | Verbindungsart | Was wird angezeigt? | Zweck |
# | --- | --- | --- |
# | INNER JOIN | Nur passende Werte werden angezeigt  | Verbindet zwei Tabellen und zeigt nur passende Werte |
# | LEFT JOIN | Alles von der linken Tabelle und nicht passende Werte in der rechten Tabelle werden mit NULL gezeigt| Zeigt alle Zeilen der linken Tabelle und ergänzt passende Daten aus der rechten Tabelle     |
# | RIGHT JOIN | Alles von der rechten Tabelle z.B alle Projekte | Zeigt alle Zeilen der rechten Tabelle und ergänzt passende Daten aus der linken Tabelle   |
# | FULL OUTER JOIN | Alle Zeilen aus beiden Tabellen erscheinen. Noah ohne Projekt. Wetterstation ohne Schüler | Zeigt alle Zeilen beider Tabellen. Nicht passende Zeilen werden mit NULL gefüllt |
# | WHERE ohne JOIN | Wie INNER JOIN | Wie INNER JOIN |
